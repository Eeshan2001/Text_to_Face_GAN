# %% [markdown]
# <a href="https://colab.research.google.com/github/Eeshan2001/Text_to_Face_GAN/blob/main/Text_To_Face_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Write your code here")
# Out:
# Write your code here
